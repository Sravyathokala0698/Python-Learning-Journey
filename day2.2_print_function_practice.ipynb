# %%
# Exercise 1: Basic Printing
# Print the following exactly
# Hello Python
#Welcome to Data Science
print("Hello Python")
print("Welcome to Data Science")
# Out:
# Hello Python
# Welcome to Data Science

# %%
# Exercise 2: Printing Variables
# Task:
#Create a variable name = "Shravya"
#Print: My name is Shravya
your_name = input("enter your name")
print("my name is:",your_name)
# Out:
# enter your name sravya
# my name is: sravya

# %%
#Exercise 3: Using f-String (Professional Way)
#Task:
#Create variables: name, age
#Print: My name is Shravya and I am 25 years old
your_name = input("enter your name")
your_age = int(input("enter your age"))
print(f"Hello,my name is {your_name} and my age is {your_age} ")
# Out:
# enter your name sravya
# enter your age 27
# Hello,my name is sravya and my age is 27

# %%
#Exercise 4: Using sep Parameter
#Print:2026-03-02
print(2026,3,2,sep='-')
# Out:
# 2026-3-2

# %%
#Exercise 5: Using end Parameter
#Task:Print:Hello Python
print("hello",end = '%')#end prevents adding new line ,also we can use end=' ',any symbol we can use
print("python")
# Out:
# hello%python

# %%
#Exercise 6: Printing Multiple Data Types
#Task:
#Create:
#name = "Shravya"
#age = 25
#height = 5.4
#is_student = True
#Print all in one line.
name = "sravya"
age = 27
height = 5.5
is_student = True
print(name,age,height,is_student)
# Out:
# sravya 27 5.5 True
