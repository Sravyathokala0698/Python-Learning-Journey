# %%
#Exercise 1: String to Integer
#Task:
#Take a number using input()
#Convert it to integer
#Add 10
#Print result
a = input("enter a number")
b=int(a)
c=b+10
print(c)
# Out:
# enter a number 10
# 20

# %%
#Exercise 2: Integer to Float
#Task:
#Create an integer variable
#Convert it into float
#Print both types
a = int(input("enter any number"))
print(type(a))
b= float(a)
print(b)
print(type(b))
# Out:
# enter any number 52
# <class 'int'>
# 52.0
# <class 'float'>

# %%
#Exercise 3: Float to Integer
#Create a float value 9.8
#Convert it into integer
#Observe output
num_1 = 9.8
num_2 = int(num_1)
print("float value is",num_1)
print("after type conversion",num_2)
# Out:
# float value is 9.8
# after type conversion 9

# %%
#Exercise 4: Number to String
#Task:
#Take a number
#Convert it into string
#Concatenate with another string
num_1 = int(input("enter any number"))
#converting num_1 to string
num_2 = str(num_1)
print("value as number",num_1)
print("value as string",num_2)
print(num_2+"python")
# Out:
# enter any number 25
# value as number 25
# value as string 25
# 25python

# %%
#Exercise 5: String to Float
#Task:String to Float
#Convert "45.67" into float and multiply by 2.
value_1 = "45.67"
value_2 = float(value_1)
print(value_2*2)
print(type(value_2))
# Out:
# 91.34
# <class 'float'>

# %%
#Exercise 7: Mixed Conversion Practice
#Task:
#Take input from user
#Convert to int
#Convert to float
#Convert to bool
#Print all types
value = input("give any number")
int_value = int(value)
float_value = int(value)
bool_value = bool(value)
print("int value is",int_value,type(int_value))
print("float value is",
